# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("../../output/output.csv", delimiter=";")

# %%
df.head()
# Out:
#      MAPPING        FUNCTION                           OBJ  WIDTH  REPEATS  \
# 0  SPHERICAL  spherical_area  octahedron.1.0.0.0.0.0.0.obj   2048     1000
# 1  SPHERICAL  spherical_area             wide_triangle.obj   2048     1000
# 2  SPHERICAL  spherical_area  octahedron.1.0.0.0.0.0.0.obj   1024     1000
# 3  SPHERICAL  spherical_area             wide_triangle.obj   1024     1000
# 4  SPHERICAL  spherical_area  octahedron.1.0.0.0.0.0.0.obj    512     1000
#
#     RMAX  GEOM_OFF?  TESS_OFF?     ALPHA  X  Y  Z  EXPECTED_RESULT  \
# 0  10000          0          0  3.141593  0  0  0        12.566371
# 1  10000          0          0  3.141593  0  0  0         1.569383
# 2  10000          0          0  3.141593  0  0  0        12.566371
# 3  10000          0          0  3.141593  0  0  0         1.569383
# 4  10000          0          0  3.141593  0  0  0        12.566371
#
#    ACTUAL_RESULT  GRAPHICS_FPS  COMPUTE_FPS  Unnamed: 16
# 0        0.00000       6006.01      2774.41          NaN
# 1        1.04894       5829.58      2908.41          NaN
# 2        0.00000      21371.60      7866.71          NaN
# 3        1.04801      20954.70      7836.74          NaN
# 4        0.00000      59740.70     22127.30          NaN

# %%
df["ERROR"] = abs(df["EXPECTED_RESULT"] - df["ACTUAL_RESULT"])/df["EXPECTED_RESULT"]

# %%
dfo = df[df["OBJ"] == "octahedron.1.0.0.0.0.0.0.obj"]
dft = df[df["OBJ"] == "wide_triangle.obj"]

# %% [markdown]
# # Performance

# %%
df_fps = df
df_fps = df_fps[df_fps["FUNCTION"] == "spherical_area"]
df_fps = df_fps[df_fps["GEOM_OFF?"] != 1]
df_fps = df_fps[df_fps["TESS_OFF?"] != 1]
df_fps = df_fps[df_fps["OBJ"] == "wide_triangle.obj"]

# %%
df_fps_cube = df_fps[df_fps["MAPPING"] == "CUBE"]
df_fps_cube.columns = [c+".C" for c in df_fps_cube.columns]
df_fps_spherical = df_fps[df_fps["MAPPING"] == "SPHERICAL"]
df_fps_spherical.columns = [c+".S" for c in df_fps_spherical.columns]

df_fps_cube["key"] = 0
df_fps_spherical["key"] = 0
df_fps_both = pd.merge(df_fps_spherical, df_fps_cube, on ="key")
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
reldiff = lambda a,b: abs((a-b)/a)
df_fps_both["W"] = df_fps_both["WIDTH.C"]/df_fps_both["WIDTH.S"]
df_fps_both["E"] = reldiff(df_fps_both["ERROR.C"],df_fps_both["ERROR.S"])
df_fps_both["GFPS"] = df_fps_both["GRAPHICS_FPS.C"]/df_fps_both["GRAPHICS_FPS.S"]
df_fps_both["CFPS"] = df_fps_both["COMPUTE_FPS.C"]/df_fps_both["COMPUTE_FPS.S"]

# %%
f = plt.figure()
ax = f.gca()
ax.set_xscale('log', basex=2)
ax.set_yscale('log', basey=2)
ax = sns.regplot(x="W",
            y="GFPS",
            ax=ax,
            data=df_fps_both,
            x_estimator=np.mean,
            fit_reg=False,
            ci=95
        )
ax.set(xlabel=r"$\frac{\mathrm{width}_{Cube}}{\mathrm{width}_{Sphere}}$")
ax.set(ylabel=r"$\frac{\mathrm{GFPS}_{Cube}}{\mathrm{GFPS}_{Sphere}}$")
f.savefig("plots/gfps_ratio.pdf")
f.savefig("plots/gfps_ratio.png")

# %%
f = plt.figure()
ax = f.gca()
ax.set_xscale('log', basex=2)
ax.set_yscale('log', basey=2)
ax = sns.regplot(x="W",
            y="CFPS",
            ax=ax,
            data=df_fps_both,
            x_estimator=np.mean,
            fit_reg=False,
            ci=95
        )
ax.set(xlabel=r"$\frac{\mathrm{width}_{Cube}}{\mathrm{width}_{Sphere}}$")
ax.set(ylabel=r"$\frac{\mathrm{CFPS}_{Cube}}{\mathrm{CFPS}_{Sphere}}$")
f.savefig("plots/cfps_ratio.pdf")

# %%
f = plt.figure()
ax = f.gca()
ax.set_xscale('log', basex=2)
ax.set_yscale('log', basey=2)
ax = sns.regplot(x="W",y="E",ax=ax,data=df_fps_both[df_fps_both["ALPHA.S"] < 0.11],x_estimator=np.mean,fit_reg=False, ci=95)
ax.set(xlabel=r"$\frac{\mathrm{width}_{Cube}}{\mathrm{width}_{Sphere}}$")
ax.set(ylabel=r"$\frac{\mathrm{error}_{Cube}}{\mathrm{error}_{Sphere}}$")
f.savefig("plots/error_ratio.pdf")
f.savefig("plots/error_ratio.png")

# %%
df_fps_both[df_fps_both["ALPHA.S"] < 0.011].to_csv("test.csv")

# %% [markdown]
# # Absolute error

# %%
df2 = df
df2["DIFF"] = np.abs(df["ACTUAL_RESULT"] - df["EXPECTED_RESULT"])
df2 = df2[df2["MAPPING"] == "SPHERICAL"]
df2 = df2[df2["FUNCTION"] == "spherical_area"]
df2 = df2[df2["OBJ"] == "wide_triangle.obj"]
df2 = df2[df2["GEOM_OFF?"] == 0]
df2 = df2[df2["TESS_OFF?"] == 0]
f = plt.figure()
ax = f.gca()

df3 = df
df3["DIFF"] = np.abs(df3["ACTUAL_RESULT"] - df3["EXPECTED_RESULT"])
df3 = df3[df3["MAPPING"] == "CUBE"]
df3 = df3[df3["FUNCTION"] == "spherical_area"]
df3 = df3[df3["OBJ"] == "wide_triangle.obj"]
for row in df3.iterrows():
    ax.plot([min(df2["ALPHA"]), np.pi/10-0.01], [row[1]["ERROR"], row[1]["ERROR"]], color="black", linewidth=1,linestyle="dashed")
    ax.text(np.pi/10, row[1]["ERROR"], "{0}x{1}".format(row[1]["WIDTH"],row[1]["WIDTH"]), fontsize=8, va='center')

ax.set_xscale('log', basex=2)
ax.set_yscale('log', basey=2)
for width in df2["WIDTH"].unique():
    df3 = df2[df2["WIDTH"] == width]
    df3 = df3[df3["ALPHA"] <= np.pi/10]
    ax.plot(df3["ALPHA"].values, df3["ERROR"].values, color="black")
    
    rmin = df3["ALPHA"].argmin()
    mx = df3.loc[rmin]["ALPHA"]
    my = df3.loc[rmin]["ERROR"]
    ax.text(mx, my+2.0**((np.log2(my)-3)), "{0}x{1}".format(width, width/2), fontsize=8)

ax.set_ylabel("Relative Error")
ax.set_xlabel(r"$\alpha_\mathrm{max}$")
f.savefig("error3.png")

# %%
df3.head()
# Out:
#        MAPPING        FUNCTION                OBJ  WIDTH  REPEATS   RMAX  \
# 79   SPHERICAL  spherical_area  wide_triangle.obj     16     1000  10000
# 143  SPHERICAL  spherical_area  wide_triangle.obj     16     1000  10000
# 207  SPHERICAL  spherical_area  wide_triangle.obj     16     1000  10000
# 271  SPHERICAL  spherical_area  wide_triangle.obj     16     1000  10000
# 335  SPHERICAL  spherical_area  wide_triangle.obj     16     1000  10000
#
#      GEOM_OFF?  TESS_OFF?     ALPHA  X  Y  Z  EXPECTED_RESULT  ACTUAL_RESULT  \
# 79           0          0  0.285599  0  0  0         1.569383        1.19324
# 143          0          0  0.149600  0  0  0         1.569383        1.19324
# 207          0          0  0.101342  0  0  0         1.569383        1.19324
# 271          0          0  0.076624  0  0  0         1.569383        1.19324
# 335          0          0  0.061600  0  0  0         1.569383        1.19324
#
#      GRAPHICS_FPS  COMPUTE_FPS  Unnamed: 16     ERROR      DIFF
# 79        81413.3      40973.5          NaN  0.239676  0.376143
# 143       80457.0      41167.5          NaN  0.239676  0.376143
# 207       78802.2      41099.8          NaN  0.239676  0.376143
# 271       78051.8      41108.3          NaN  0.239676  0.376143
# 335       75976.3      40909.8          NaN  0.239676  0.376143
