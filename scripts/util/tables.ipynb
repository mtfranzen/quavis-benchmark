# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import brewer2mpl
from matplotlib import rc
import matplotlib
rc('text', usetex=True)
matplotlib.rcParams['text.usetex'] = True 
matplotlib.rcParams['text.latex.preamble'] = '\usepackage{libertine}' 
plt.style.use('bmh')
#plt.rcParams['axes.facecolor'] = 'none'
plt.rcParams['grid.alpha'] = '0.5'

# %%
df = pd.read_csv("../../output/output.csv", delimiter=";")

# %%
df.head()
# Out:
#      MAPPING        FUNCTION                           OBJ  WIDTH  REPEATS  \
# 0  SPHERICAL  spherical_area  octahedron.1.0.0.0.0.0.0.obj   2048     1000
# 1  SPHERICAL  spherical_area             wide_triangle.obj   2048     1000
# 2  SPHERICAL  spherical_area  octahedron.1.0.0.0.0.0.0.obj   1024     1000
# 3  SPHERICAL  spherical_area             wide_triangle.obj   1024     1000
# 4  SPHERICAL  spherical_area  octahedron.1.0.0.0.0.0.0.obj    512     1000
#
#     RMAX  GEOM_OFF?  TESS_OFF?     ALPHA  X  Y  Z  EXPECTED_RESULT  \
# 0  10000          0          0  3.141593  0  0  0        12.566371
# 1  10000          0          0  3.141593  0  0  0         1.569383
# 2  10000          0          0  3.141593  0  0  0        12.566371
# 3  10000          0          0  3.141593  0  0  0         1.569383
# 4  10000          0          0  3.141593  0  0  0        12.566371
#
#    ACTUAL_RESULT  GRAPHICS_FPS  COMPUTE_FPS  Unnamed: 16
# 0      12.566300       4878.19      2841.33          NaN
# 1       0.998807       6114.56      2885.77          NaN
# 2      12.566300      14389.90      8311.65          NaN
# 3       0.997924      22096.00      8479.46          NaN
# 4      12.566200      43196.50     22031.30          NaN

# %%
df["ERROR"] = abs(df["EXPECTED_RESULT"] - df["ACTUAL_RESULT"])/df["EXPECTED_RESULT"]

# %%
dfo = df[df["OBJ"] == "octahedron.1.0.0.0.0.0.0.obj"]
dft = df[df["OBJ"] == "wide_triangle.obj"]

# %% [markdown]
# # Octahedron - Tessellation / Geometry effects

# %%
df_fps = dfo
df_fps = df_fps[df_fps["FUNCTION"] == "volume"]
df_fps = df_fps[df_fps["MAPPING"] == "SPHERICAL"]

df_t = df_fps[df_fps["TESS_OFF?"] == 1]
df_t = df_t[df_t["GEOM_OFF?"] == 0]

df_g = df_fps[df_fps["TESS_OFF?"] == 0]
df_g = df_g[df_g["GEOM_OFF?"] == 1]

df_b = df_fps[df_fps["TESS_OFF?"] == 1]
df_b = df_b[df_b["GEOM_OFF?"] == 1]

df_n = df_fps[df_fps["TESS_OFF?"] == 0]
df_n = df_n[df_n["GEOM_OFF?"] == 0]

# %%
df_t
# Out:
#         MAPPING FUNCTION                           OBJ  WIDTH  REPEATS   RMAX  \
# 1936  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   2048     1000  10000
# 1938  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   1024     1000  10000
# 1940  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    512     1000  10000
# 1942  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    256     1000  10000
# 1944  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    128     1000  10000
# 1946  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     64     1000  10000
# 1948  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     32     1000  10000
# 1950  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     16     1000  10000
# 2000  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   2048     1000  10000
# 2002  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   1024     1000  10000
# 2004  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    512     1000  10000
# 2006  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    256     1000  10000
# 2008  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    128     1000  10000
# 2010  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     64     1000  10000
# 2012  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     32     1000  10000
# 2014  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     16     1000  10000
# 2064  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   2048     1000  10000
# 2066  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   1024     1000  10000
# 2068  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    512     1000  10000
# 2070  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    256     1000  10000
# 2072  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    128     1000  10000
# 2074  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     64     1000  10000
# 2076  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     32     1000  10000
# 2078  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     16     1000  10000
# 2128  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   2048     1000  10000
# 2130  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   1024     1000  10000
# 2132  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    512     1000  10000
# 2134  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    256     1000  10000
# 2136  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    128     1000  10000
# 2138  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     64     1000  10000
# ...         ...      ...                           ...    ...      ...    ...
# 3604  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    512     1000  10000
# 3606  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    256     1000  10000
# 3608  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    128     1000  10000
# 3610  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     64     1000  10000
# 3612  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     32     1000  10000
# 3614  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     16     1000  10000
# 3664  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   2048     1000  10000
# 3666  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   1024     1000  10000
# 3668  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    512     1000  10000
# 3670  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    256     1000  10000
# 3672  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    128     1000  10000
# 3674  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     64     1000  10000
# 3676  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     32     1000  10000
# 3678  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     16     1000  10000
# 3728  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   2048     1000  10000
# 3730  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   1024     1000  10000
# 3732  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    512     1000  10000
# 3734  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    256     1000  10000
# 3736  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    128     1000  10000
# 3738  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     64     1000  10000
# 3740  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     32     1000  10000
# 3742  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     16     1000  10000
# 3792  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   2048     1000  10000
# 3794  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj   1024     1000  10000
# 3796  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    512     1000  10000
# 3798  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    256     1000  10000
# 3800  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj    128     1000  10000
# 3802  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     64     1000  10000
# 3804  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     32     1000  10000
# 3806  SPHERICAL   volume  octahedron.1.0.0.0.0.0.0.obj     16     1000  10000
#
#       GEOM_OFF?  TESS_OFF?     ALPHA  X  Y  Z  EXPECTED_RESULT  ACTUAL_RESULT  \
# 1936          0          1  3.141593  0  0  0         1.333333        3.61533
# 1938          0          1  3.141593  0  0  0         1.333333        3.61639
# 1940          0          1  3.141593  0  0  0         1.333333        3.61850
# 1942          0          1  3.141593  0  0  0         1.333333        3.62257
# 1944          0          1  3.141593  0  0  0         1.333333        3.63040
# 1946          0          1  3.141593  0  0  0         1.333333        3.64445
# 1948          0          1  3.141593  0  0  0         1.333333        3.67249
# 1950          0          1  3.141593  0  0  0         1.333333        3.69625
# 2000          0          1  0.285599  0  0  0         1.333333        3.61533
# 2002          0          1  0.285599  0  0  0         1.333333        3.61639
# 2004          0          1  0.285599  0  0  0         1.333333        3.61850
# 2006          0          1  0.285599  0  0  0         1.333333        3.62257
# 2008          0          1  0.285599  0  0  0         1.333333        3.63040
# 2010          0          1  0.285599  0  0  0         1.333333        3.64445
# 2012          0          1  0.285599  0  0  0         1.333333        3.67249
# 2014          0          1  0.285599  0  0  0         1.333333        3.69625
# 2064          0          1  0.149600  0  0  0         1.333333        3.61533
# 2066          0          1  0.149600  0  0  0         1.333333        3.61639
# 2068          0          1  0.149600  0  0  0         1.333333        3.61850
# 2070          0          1  0.149600  0  0  0         1.333333        3.62257
# 2072          0          1  0.149600  0  0  0         1.333333        3.63040
# 2074          0          1  0.149600  0  0  0         1.333333        3.64445
# 2076          0          1  0.149600  0  0  0         1.333333        3.67249
# 2078          0          1  0.149600  0  0  0         1.333333        3.69625
# 2128          0          1  0.101342  0  0  0         1.333333        3.61533
# 2130          0          1  0.101342  0  0  0         1.333333        3.61639
# 2132          0          1  0.101342  0  0  0         1.333333        3.61850
# 2134          0          1  0.101342  0  0  0         1.333333        3.62257
# 2136          0          1  0.101342  0  0  0         1.333333        3.63040
# 2138          0          1  0.101342  0  0  0         1.333333        3.64445
# ...         ...        ...       ... .. .. ..              ...            ...
# 3604          0          1  0.012037  0  0  0         1.333333        3.61850
# 3606          0          1  0.012037  0  0  0         1.333333        3.62257
# 3608          0          1  0.012037  0  0  0         1.333333        3.63040
# 3610          0          1  0.012037  0  0  0         1.333333        3.64445
# 3612          0          1  0.012037  0  0  0         1.333333        3.67249
# 3614          0          1  0.012037  0  0  0         1.333333        3.69625
# 3664          0          1  0.011593  0  0  0         1.333333        3.61533
# 3666          0          1  0.011593  0  0  0         1.333333        3.61639
# 3668          0          1  0.011593  0  0  0         1.333333        3.61850
# 3670          0          1  0.011593  0  0  0         1.333333        3.62257
# 3672          0          1  0.011593  0  0  0         1.333333        3.63040
# 3674          0          1  0.011593  0  0  0         1.333333        3.64445
# 3676          0          1  0.011593  0  0  0         1.333333        3.67249
# 3678          0          1  0.011593  0  0  0         1.333333        3.69625
# 3728          0          1  0.011180  0  0  0         1.333333        3.61533
# 3730          0          1  0.011180  0  0  0         1.333333        3.61639
# 3732          0          1  0.011180  0  0  0         1.333333        3.61850
# 3734          0          1  0.011180  0  0  0         1.333333        3.62257
# 3736          0          1  0.011180  0  0  0         1.333333        3.63040
# 3738          0          1  0.011180  0  0  0         1.333333        3.64445
# 3740          0          1  0.011180  0  0  0         1.333333        3.67249
# 3742          0          1  0.011180  0  0  0         1.333333        3.69625
# 3792          0          1  0.010796  0  0  0         1.333333        3.61533
# 3794          0          1  0.010796  0  0  0         1.333333        3.61639
# 3796          0          1  0.010796  0  0  0         1.333333        3.61850
# 3798          0          1  0.010796  0  0  0         1.333333        3.62257
# 3800          0          1  0.010796  0  0  0         1.333333        3.63040
# 3802          0          1  0.010796  0  0  0         1.333333        3.64445
# 3804          0          1  0.010796  0  0  0         1.333333        3.67249
# 3806          0          1  0.010796  0  0  0         1.333333        3.69625
#
#       GRAPHICS_FPS  COMPUTE_FPS  Unnamed: 16     ERROR
# 1936       5536.49      2861.19          NaN  1.711498
# 1938      15785.10      8106.82          NaN  1.712293
# 1940      53313.40     22189.20          NaN  1.713875
# 1942      73030.00     35526.50          NaN  1.716928
# 1944      78529.90     38061.90          NaN  1.722800
# 1946      79497.60     39272.70          NaN  1.733338
# 1948      79719.40     40286.80          NaN  1.754368
# 1950      79126.40     40628.90          NaN  1.772188
# 2000       5555.74      2858.73          NaN  1.711498
# 2002      15741.10      8196.52          NaN  1.712293
# 2004      53364.60     22124.40          NaN  1.713875
# 2006      72280.40     34609.30          NaN  1.716928
# 2008      72865.10     36652.90          NaN  1.722800
# 2010      80269.70     39478.90          NaN  1.733338
# 2012      80334.20     38543.10          NaN  1.754368
# 2014      80032.00     40903.10          NaN  1.772188
# 2064       5554.23      2977.24          NaN  1.711498
# 2066      15794.50      8272.67          NaN  1.712293
# 2068      53253.80     22088.70          NaN  1.713875
# 2070      72406.10     35713.00          NaN  1.716928
# 2072      78406.80     35826.90          NaN  1.722800
# 2074      79840.30     39444.60          NaN  1.733338
# 2076      74206.00     37828.60          NaN  1.754368
# 2078      79929.70     40657.00          NaN  1.772188
# 2128       5558.61      2849.85          NaN  1.711498
# 2130      15812.50      8109.58          NaN  1.712293
# 2132      51355.80     22078.00          NaN  1.713875
# 2134      72611.10     35716.80          NaN  1.716928
# 2136      78382.20     38146.10          NaN  1.722800
# 2138      73195.70     39265.00          NaN  1.733338
# ...            ...          ...          ...       ...
# 3604      53341.90     22155.30          NaN  1.713875
# 3606      72881.00     35454.70          NaN  1.716928
# 3608      78406.80     37012.40          NaN  1.722800
# 3610      79636.90     37690.30          NaN  1.733338
# 3612      79624.20     40202.60          NaN  1.754368
# 3614      81340.50     40929.90          NaN  1.772188
# 3664       5546.83      2856.28          NaN  1.711498
# 3666      15777.40      8141.33          NaN  1.712293
# 3668      53126.50     21772.70          NaN  1.713875
# 3670      72722.00     35774.30          NaN  1.716928
# 3672      78290.10     37444.80          NaN  1.722800
# 3674      78833.30     39528.80          NaN  1.733338
# 3676      79377.70     39183.40          NaN  1.754368
# 3678      79554.50     41145.50          NaN  1.772188
# 3728       5550.50      2849.88          NaN  1.711498
# 3730      15775.40      8113.33          NaN  1.712293
# 3732      53447.40     21519.30          NaN  1.713875
# 3734      73174.30     34605.70          NaN  1.716928
# 3736      78339.20     38106.90          NaN  1.722800
# 3738      79277.00     39334.50          NaN  1.733338
# 3740      80083.30     40454.70          NaN  1.754368
# 3742      81195.20     40466.20          NaN  1.772188
# 3792       5554.14      2965.76          NaN  1.711498
# 3794      15766.90      8284.32          NaN  1.712293
# 3796      52997.00     22236.10          NaN  1.713875
# 3798      72170.90     34869.90          NaN  1.716928
# 3800      77839.20     37745.80          NaN  1.722800
# 3802      79466.00     39412.00          NaN  1.733338
# 3804      80198.90     40373.00          NaN  1.754368
# 3806      79668.60     40681.80          NaN  1.772188
#
# [240 rows x 18 columns]

# %% [markdown]
# # Volume - Octahedron

# %%
df2 = dfo
df2["DIFF"] = np.abs(df2["ACTUAL_RESULT"] - df2["EXPECTED_RESULT"])
df2 = df2[df2["MAPPING"] == "SPHERICAL"]
df2 = df2[df2["FUNCTION"] == "volume"]
df2 = df2[df2["GEOM_OFF?"] == 1]
df2 = df2[df2["TESS_OFF?"] == 1]
f = plt.figure()
ax = f.gca()

df3 = dfo
df3["DIFF"] = np.abs(df3["ACTUAL_RESULT"] - df3["EXPECTED_RESULT"])
df3 = df3[df3["MAPPING"] == "CUBE"]
df3 = df3[df3["FUNCTION"] == "volume"]
for row in df3.iterrows():
    ax.plot([min(df2["ALPHA"]), np.pi/10], [row[1]["ERROR"], row[1]["ERROR"]], color="black", linewidth=0.5,linestyle="dashed")
    ax.text(np.pi/10, row[1]["ERROR"], "{0}x{1}".format(row[1]["WIDTH"],row[1]["WIDTH"]), fontsize=8, va='center', ha='right')

marker_selection = ['D','s','v','o','^','<','>','p']
color_selection = brewer2mpl.get_map('Set1', 'qualitative', 8).mpl_colors

widths = df2["WIDTH"].unique()
markers = [marker_selection[i] for i in range(len(widths))]
colors = [color_selection[i] for i in range(len(widths))]
    
for width, color, marker in zip(widths, colors, markers):
    if width <= 32:
        continue
    df3 = df2[df2["WIDTH"] == width]
    df3 = df3[df3["ALPHA"] <= np.pi/10]
    ax.scatter(df3["ALPHA"].values, df3["ERROR"].values, color=color, marker=marker, s=10, label=r"{0}x{1}".format(width, width/2))
    
    rmin = df3["ALPHA"].argmin()
    mx = df3.loc[rmin]["ALPHA"]
    my = df3.loc[rmin]["ERROR"]
    #ax.text(mx, my+2.0**((np.log2(my)-3)), "{0}x{1}".format(width, width/2), fontsize=8)
    
    df4 = df3[df3["ALPHA"] > 0.025]
    X = df4["ALPHA"].values
    Y = df4["ERROR"].values
    l = np.linspace(2**-7, 2**-1, 100)
    z = np.polyfit(X, Y, 2)
    p = np.poly1d(z)
    plt.plot(l,p(l),color=color,linewidth=1)
    print width, z

ax.set_xscale('log', basex=10)
ax.set_yscale('log', basey=10)
ly = ax.set_ylabel(r"$\eta_V$")
lx = ax.set_xlabel(r"$\alpha_\mathrm{max}$")
ax.set_title(r'Volume Error for the Octahedron Testcase ')
ax.set_xlim((2**-7,2**-1))
lg = ax.legend(fontsize=8, bbox_to_anchor=(1.25,1.02))
ax.invert_xaxis()
f.savefig("plots/volume_error_octahedron.pdf", bbox_extra_artists=(lg,lx,ly), bbox_inches='tight')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# 2048 [  7.96454527e-15  -3.94819218e-15   4.04607500e-01]
# 1024 [  9.32545149e-16  -2.73336382e-15   4.04930000e-01]
# 512 [  7.08180422e-15  -3.94819218e-15   4.05380000e-01]
# 256 [  1.31177130e-14  -5.46672764e-15   4.06002500e-01]
# 128 [  3.88803736e-15  -3.64448509e-15   4.07802500e-01]
# 64 [  2.22639387e-14  -8.80750564e-15   4.17740000e-01]

# %% [markdown]
# # FPS - Octahedron

# %%
df2 = dfo
df2["DIFF"] = np.abs(df["ACTUAL_RESULT"] - df["EXPECTED_RESULT"])
df2 = df2[df2["MAPPING"] == "SPHERICAL"]
df2 = df2[df2["FUNCTION"] == "volume"]
df2 = df2[df2["GEOM_OFF?"] == 0]
df2 = df2[df2["TESS_OFF?"] == 0]
f = plt.figure()
ax = f.gca()

df3 = dfo
df3["DIFF"] = np.abs(df3["ACTUAL_RESULT"] - df3["EXPECTED_RESULT"])
df3 = df3[df3["MAPPING"] == "CUBE"]
df3 = df3[df3["FUNCTION"] == "volume"]
for row in df3.iterrows():
    ax.plot([min(df2["ALPHA"]), np.pi/10], [row[1]["GRAPHICS_FPS"], row[1]["GRAPHICS_FPS"]], color="black", linewidth=0.5,linestyle="dashed")
    ax.text(np.pi/10, row[1]["GRAPHICS_FPS"], "{0}x{1}".format(row[1]["WIDTH"],row[1]["WIDTH"]), fontsize=8, va='center', ha='right')
marker_selection = ['D','s','v','o','^','<','>','p']

color_selection = brewer2mpl.get_map('Set1', 'qualitative', 8).mpl_colors

widths = df2["WIDTH"].unique()
markers = [marker_selection[i] for i in range(len(widths))]
colors = [color_selection[i] for i in range(len(widths))]
    
for width, color, marker in zip(widths, colors, markers):
    if width <= 32:
        continue
    df3 = df2[df2["WIDTH"] == width]
    df3 = df3[df3["ALPHA"] <= np.pi/10]
    ax.scatter(df3["ALPHA"].values, df3["GRAPHICS_FPS"].values, color=color, marker=marker, s=4, label="{0}x{1}".format(width, width/2))
    
    rmin = df3["ALPHA"].argmin()
    mx = df3.loc[rmin]["ALPHA"]
    my = df3.loc[rmin]["GRAPHICS_FPS"]
    #ax.text(mx, my+10.0**((np.log10(my)-3)), "{0}x{1}".format(width, width/2), fontsize=8)
    
ax.set_xscale('log', basex=10)
ax.set_yscale('log', basex=10)
ly=ax.set_ylabel("Rendering FPS")
lx=ax.set_xlabel(r"$\alpha_\mathrm{max}$")
lg=ax.legend(fontsize=8, bbox_to_anchor=(1.25,1.02))
ax.set_title(r'Rendering FPS for the Octahedron Testcase')
ax.invert_xaxis()
f.savefig("plots/volume_fps_octahedron.pdf", bbox_extra_artists=(lg,lx,ly), bbox_inches='tight')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # Error Triangle

# %%
df2 = dft
df2["DIFF"] = np.abs(df["ACTUAL_RESULT"] - df["EXPECTED_RESULT"])
df2 = df2[df2["MAPPING"] == "SPHERICAL"]
df2 = df2[df2["FUNCTION"] == "spherical_area"]
df2 = df2[df2["GEOM_OFF?"] == 0]
df2 = df2[df2["TESS_OFF?"] == 0]
f = plt.figure()
ax = f.gca()

df3 = dft
df3["DIFF"] = np.abs(df3["ACTUAL_RESULT"] - df3["EXPECTED_RESULT"])
df3 = df3[df3["MAPPING"] == "CUBE"]
df3 = df3[df3["FUNCTION"] == "spherical_area"]
for row in df3.iterrows():
    ax.plot([min(df2["ALPHA"]), np.pi/10], [row[1]["ERROR"], row[1]["ERROR"]], color="black", linewidth=0.5,linestyle="dashed")
    ax.text(np.pi/10, row[1]["ERROR"], "{0}x{1}".format(row[1]["WIDTH"],row[1]["WIDTH"]), fontsize=8, va='center', ha='right')

marker_selection = ['D','s','v','o','^','<','>','p']
color_selection = brewer2mpl.get_map('Set1', 'qualitative', 8).mpl_colors

widths = df2["WIDTH"].unique()
markers = [marker_selection[i] for i in range(len(widths))]
colors = [color_selection[i] for i in range(len(widths))]
    
for width, color, marker in zip(widths, colors, markers):
    if width <= 32:
        continue
    df3 = df2[df2["WIDTH"] == width]
    df3 = df3[df3["ALPHA"] <= np.pi/10]
    ax.scatter(df3["ALPHA"].values, df3["ERROR"].values, color=color, marker=marker, s=4, label="{0}x{1}".format(width, width/2))
    
    rmin = df3["ALPHA"].argmin()
    mx = df3.loc[rmin]["ALPHA"]
    my = df3.loc[rmin]["ERROR"]
    #ax.text(mx, my+2.0**((np.log2(my)-3)), "{0}x{1}".format(width, width/2), fontsize=8)
    
    df4 = df3[df3["ALPHA"] > 0.025]
    X = df4["ALPHA"].values
    Y = df4["ERROR"].values
    l = np.linspace(2**-7, 2**-1, 1000)
    z = np.polyfit(X, Y, 1)
    p = np.poly1d(z)
    plt.plot(l,p(l),color=color,linewidth=1)

ax.set_xscale('log', basex=10)
ax.set_yscale('log', basey=10)
ly=ax.set_ylabel(r"$\eta_A$")
lx=ax.set_xlabel(r"$\alpha_\mathrm{max}$")
ax.set_title(r'Area Error for the Triangle Testcase ')
ax.set_xlim((2**-7,2**-1))
ax.set_ylim((10**-3,10**-1))
lg=ax.legend(fontsize=8, bbox_to_anchor=(1.25,1.02))
ax.invert_xaxis()
f.savefig("plots/area_error_triangle.pdf", bbox_extra_artists=(lg,lx,ly), bbox_inches='tight')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %% [markdown]
# # FPS - Triangle

# %%
df2 = dft
df2["DIFF"] = np.abs(df["ACTUAL_RESULT"] - df["EXPECTED_RESULT"])
df2 = df2[df2["MAPPING"] == "SPHERICAL"]
df2 = df2[df2["FUNCTION"] == "spherical_area"]
df2 = df2[df2["GEOM_OFF?"] == 0]
df2 = df2[df2["TESS_OFF?"] == 0]
f = plt.figure()
ax = f.gca()

df3 = dft
df3["DIFF"] = np.abs(df3["ACTUAL_RESULT"] - df3["EXPECTED_RESULT"])
df3 = df3[df3["MAPPING"] == "CUBE"]
df3 = df3[df3["FUNCTION"] == "spherical_area"]
for row in df3.iterrows():
    ax.plot([min(df2["ALPHA"]), np.pi/10], [row[1]["GRAPHICS_FPS"], row[1]["GRAPHICS_FPS"]], color="black", linewidth=0.5,linestyle="dashed")
    ax.text(np.pi/10, row[1]["GRAPHICS_FPS"], "{0}x{1}".format(row[1]["WIDTH"],row[1]["WIDTH"]), fontsize=8, va='center', ha='right')

marker_selection = ['D','s','v','o','^','<','>','p']
color_selection = brewer2mpl.get_map('Set1', 'qualitative', 8).mpl_colors
widths = df2["WIDTH"].unique()
markers = [marker_selection[i] for i in range(len(widths))]
colors = [color_selection[i] for i in range(len(widths))]
    
for width, color, marker in zip(widths, colors, markers):
    if width <= 32:
        continue
    df3 = df2[df2["WIDTH"] == width]
    df3 = df3[df3["ALPHA"] <= np.pi/10]
    ax.scatter(df3["ALPHA"].values, df3["GRAPHICS_FPS"].values, color=color, marker=marker, s=4, label="{0}x{1}".format(width, width/2))

ax.set_xscale('log', basex=10)
ax.set_yscale('log', basex=10)
ly=ax.set_ylabel("FPS")
lx=ax.set_xlabel(r"$\alpha_\mathrm{max}$")
lg=ax.legend(fontsize=8, bbox_to_anchor=(1.25,1.02))
ax.set_title(r'Rendering FPS for the Triangle Testcase')
ax.invert_xaxis()
f.savefig("plots/area_fps_triangle.pdf", bbox_extra_artists=(lg,lx,ly), bbox_inches='tight')
# Out:
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
# /usr/local/lib/python2.7/dist-packages/ipykernel/__main__.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
